# %%
import os
from groq import Groq

# %%
client = Groq(
    api_key=os.environ.get("GROQ_API_KEY")
)

# %%
def run_chatbot(memory_thres=10):
    messages=[
        {
            "role": "system",
            "content":
                "You are a helpful assistant working at Bina Nusantara University. Your task is to answer questions about the administration things, such as registration, tuition fee, thesis enrollment, graduation, and so on"
        },
    ]

    print("--- Binus SSC Bot ---")
    print("> Bot: Hi! What can I help you today? (type 'exit' or 'quit' to end the conversation)")

    while True:
        user_input = input("> You: ")
        if user_input.lower() in ["exit", "quit"]:
            print("Goodbye!")
            break
        
        messages.append({
            "role": "user",
            "content": user_input
        })

        try:
            response = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                messages=messages,
                temperature=0.5,
                max_tokens=1024,
                stream=False
            )

            bot_response = response.choices[0].message.content
            print(f"Bot: {bot_response}")

            messages.append({
                "role": "assistant",
                "content": bot_response
            })

            # remove old history
            if len(messages) > memory_thres:
                del messages[1:3]

        except Exception as e:
            print(f"Error: {e}")

# %%
if __name__ == "__main__":
    run_chatbot()
# Out:
# --- Binus SSC Bot ---
# > Bot: Hi! What can I help you today? (type 'exit' or 'quit' to end the conversation)
# Bot: I'd be happy to help you with that. However, I need to check the latest information from our university's event calendar. According to the latest update, the Binus graduation batch 75 is scheduled to be held on [insert date, e.g., October 2024]. Please note that the date may be subject to change, and I recommend checking the official Binus website or contacting the Student Affairs Office for the most up-to-date information. Would you like me to provide more details or direct you to the relevant contact person?
# Bot: The tuition fee for Binus University can vary depending on the program, major, and semester. For the Computer Science major, the tuition fee per semester is as follows:
#
# * For International Program: around IDR 65,000,000 - IDR 75,000,000 per semester (approximately USD 4,300 - USD 5,000)
# ...
