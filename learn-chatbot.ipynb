# %%
import os
from groq import Groq

# %%
client = Groq(
    api_key=os.environ.get("GROQ_API_KEY")
)

# %%
response = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain annoying dog from undertale"
        }
    ],
    model="llama-3.3-70b-versatile"
)

print(response.choices[0].message.content)
# Out:
# The Annoying Dog is a character in the popular video game Undertale, created by Toby Fox. It's a mysterious, small, and, as the name suggests, annoying canine creature that appears throughout the game.
#
# The Annoying Dog is known for its bizarre and often humorous behavior. It tends to show up at unexpected times, usually to provide comedic relief or to break the tension in a scene. The dog's actions are often illogical and random, which adds to its annoying yet endearing nature.
#
# Throughout the game, the Annoying Dog can be found in various locations, such as in the Ruins, the Snowdin Forest, or even in the player's own home. It often appears to offer useless or confusing advice, make silly comments, or simply to distract the player from their quest.
#
# One of the most interesting aspects of the Annoying Dog is its apparent ability to manipulate the game's mechanics. It can sometimes alter the player's progress, change the environment, or even affect the behavior of other characters. However, the dog's intentions and motivations are never fully explained, leaving the player to wonder about its true purpose in the game.
#
# The Annoying Dog has become a fan favorite in the Undertale community, with many players finding its quirky personality and antics to be a delightful addition to the game. Despite its annoying nature, the dog has a certain charm that makes it hard to dislike, and its mysterious presence adds to the game's overall charm and depth.
